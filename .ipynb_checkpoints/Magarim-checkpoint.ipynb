# %%
import camelot
import pandas as pd
import os

# %%
for file in os.listdir('pdfs'):
    print(file)
# Out:
# 1.pdf
# 2.pdf
# 3.pdf
# 4.pdf
# 5.pdf
# 6.pdf

# %%
tables = camelot.read_pdf('magarim.pdf')

# %%
tables[0].to_csv('magarim.csv', encoding='windows-1255')
df = tables[0].df

# %%
df[2] = df[2].apply(lambda x: x.replace('''\n''',''))
df[3] = df[3].apply(lambda x: x.replace('''\n''',''))

# %%
df[2] = df[2].apply(lambda x: x[::-1])
df[3] = df[3].apply(lambda x: x[::-1])

# %%
df
# Out:
#              0       1                                                  2  \
# 0   יזכרמ .צ.נ                                                       הסבר
# 1            Y       X
# 2       792392  256762  קבועה של מינים בסיכון עושר ושפע מיני עופות מים...
# 3       791019  258455  קבועה של מינים בסיכון עושר ושפע מיני עופות מים...
# 4       787977  261043  קבועה של מינים בסיכון עושר ושפע מיני עופות מים...
# 5       786877  253370  עושר ושפע מיני עופות מים גבוה  מיקום באזור שבע...
# 6       783238  257139  עושר ושפע מיני עופות מים גבוה  מיקום באזור שבע...
# 7       782033  260439  קבועה של מינים בסיכון עושר ושפע מיני עופות מים...
# 8       776600  254800  עושר ושפע מיני עופות מים גבוה  מיקום באזור שבע...
# 9       760500  282000     הסטורי ניזון ממעיינות מקומיים על חשבון גוף מים
# 10      746600  273800                                 קינון מינים בסיכון
# 11      769188  243263  קבועה של מינים בסיכון עושר ושפע מיני עופות מים...
# ...
